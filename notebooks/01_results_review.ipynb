# %% [markdown]
# # Ibadan LULC final results review
#
# This notebook reads the frozen final tables used by the public repository.

# %%
from pathlib import Path
import pandas as pd
ROOT = Path('..')
summary = pd.read_csv(ROOT/'outputs/tables/lulc_area_change_summary.csv')
summary

# %%
accuracy = pd.read_csv(ROOT/'outputs/tables/classification_accuracy.csv')
accuracy

# %%
transition = pd.read_csv(ROOT/'outputs/tables/transition_matrix_sqkm.csv', index_col=0)
transition

# %% [markdown]
# For the authoritative final reconstruction workflow and validation design, see `docs/METHODOLOGY.md` and `docs/RESULTS.md`. The superseded single-script GEE workflow was removed from the public repository.
