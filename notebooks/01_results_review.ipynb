# %% [markdown]
# # Ibadan LULC results review
#
# This notebook checks the final area statistics and classification outputs included in the repository.

# %%
from pathlib import Path
import pandas as pd
ROOT = Path('..')
summary = pd.read_csv(ROOT/'outputs/tables/lulc_area_change_summary.csv')
summary

# %%
accuracy = pd.read_csv(ROOT/'outputs/tables/classification_accuracy.csv')
accuracy

# %%
transition = pd.read_csv(ROOT/'outputs/tables/transition_matrix_sqkm.csv', index_col=0)
transition

# %% [markdown]
# The full classification and export workflow is available in `scripts/gee/ibadan_lulc_final_gee_script.js`.
